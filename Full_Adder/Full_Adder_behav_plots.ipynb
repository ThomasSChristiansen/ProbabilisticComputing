# %% [markdown]
# # Full Adder Behavoural plots

# %%
import Scripts.generate_bar_plots as gbp
label_mapping = {
    (-1.0,-1.0,-1.0,-1.0,-4.0) : 'Floating State',
}
gbp.generate_bar_plots('Full_Adder.csv', label_mapping, savefig=False, save_csv=True)
# Out:
# Labeled results saved to 'Full_Adder_behav_counts.csv'

# %%
import Scripts.generate_bar_plots as gbp
label_mapping = {
    (-1.0,-1.0,-1.0,-1.0,-4.0) : 'Floating State',
}
gbp.generate_bar_plots('Full_Adder_long.csv', label_mapping, savefig=False, save_csv=True)
# Out:
# Labeled results saved to 'Full_Adder_long_behav_counts.csv'
