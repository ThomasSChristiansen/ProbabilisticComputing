# %%
import Scripts.comparison as comp
comp.comparison("Full_Adder_behav_counts.csv","Full_Adder_Python_Sim_counts.csv", savefig=True, filename="Full_Adder_Comparison")
# Out:
# Saved plot: Plots/Full_Adder_Comparison_Floating_State.png
