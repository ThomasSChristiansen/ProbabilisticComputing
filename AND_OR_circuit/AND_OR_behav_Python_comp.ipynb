# %%
import Scripts.comparison as comp
comp.comparison("AND_OR_out_behav_counts.csv","AND_OR_Python_Sim.csv", savefig=True, filename="AND_OR_Comparison")
# Out:
# Saved plot: Plots/AND_OR_Comparison_A=0,_B=0,_D=0.png
# Saved plot: Plots/AND_OR_Comparison_A=0,_B=0,_D=1.png
# Saved plot: Plots/AND_OR_Comparison_A=0,_B=1,_D=0.png
# Saved plot: Plots/AND_OR_Comparison_A=0,_B=1,_D=1.png
# Saved plot: Plots/AND_OR_Comparison_A=1,_B=0,_D=0.png
# Saved plot: Plots/AND_OR_Comparison_A=1,_B=0,_D=1.png
# Saved plot: Plots/AND_OR_Comparison_A=1,_B=1,_D=0.png
# Saved plot: Plots/AND_OR_Comparison_A=1,_B=1,_D=1.png
# Saved plot: Plots/AND_OR_Comparison_C=0,_E=0.png
# Saved plot: Plots/AND_OR_Comparison_C=0,_E=1.png
# Saved plot: Plots/AND_OR_Comparison_C=1,_E=0.png
# Saved plot: Plots/AND_OR_Comparison_C=1,_E=1.png
# Saved plot: Plots/AND_OR_Comparison_Floating_State.png
