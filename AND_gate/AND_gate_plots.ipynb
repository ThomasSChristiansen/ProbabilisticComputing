# %% [markdown]
# # Probabilities of floating AND-gate

# %%
import Scripts.generate_bar_plots as gbp

label_mapping = {
    # (-16.0, -16.0, -6.0): 'A=0, B=0 (I0=1)',
    # (-16.0, 15.875, -6.0): 'A=0, B=1 (I0=1)',
    (0.0, 0.0, -16.0): 'C=0 (I0=1)',
    (0.0, 0.0, -6.0): 'Floating State (I0=1)',
    # (0.0, 0.0, 0.0): 'Unconstrained (I0=0)',
    # (0.0, 0.0, 15.875): 'C=1 (I0=1)',
    # (15.875, -16.0, -6.0): 'A=1, B=0 (I0=1)',
    (15.875, 15.875, -6.0): 'A=1, B=1 (I0=1)',
}
gbp.generate_bar_plots('AND_float_AB11_C0.csv', label_mapping, savefig=False, save_csv=False, figWidth=8, selected_bits=None)

# %% [markdown]
# # All possible states

# %%
import Scripts.generate_bar_plots as gbp

label_mapping = {
    (-16.0, -16.0, -6.0): 'A=0, B=0 (I0=1)',
    (-16.0, 15.875, -6.0): 'A=0, B=1 (I0=1)',
    (0.0, 0.0, -16.0): 'C=0 (I0=1)',
    (0.0, 0.0, -6.0): 'Floating State (I0=1)',
    (0.0, 0.0, 0.0): 'Unconstrained (I0=0)',
    (0.0, 0.0, 15.875): 'C=1 (I0=1)',
    (15.875, -16.0, -6.0): 'A=1, B=0 (I0=1)',
    (15.875, 15.875, -6.0): 'A=1, B=1 (I0=1)',
}
gbp.generate_bar_plots('AND_all_states.csv', label_mapping, savefig=False, save_csv=False, figWidth=8, selected_bits=None)
