# %% [markdown]
# # Vivado Simulation output of a single P-bit
# 3 state of floating, bias toward 1, and bias toward 0

# %%
import generate_plots_pbit
generate_plots_pbit.generate_plots_pbit('P_bit_uncon_float_1_0.csv',savefig=True)
