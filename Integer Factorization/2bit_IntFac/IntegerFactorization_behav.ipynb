# %%
import Scripts.generate_bar_plots as gbp

label_mapping = {
    ( 0., 0., 0., 0., -6., -1., -1., -4.) : "Floating State",
    ( 0., 0., 0., 0., -16., 15.875, 15.875, -16.) : "Output = 6, factors (3x2,2x3)",
    ( 0., 0., 0., 0., 15.875, -16., -16., 15.875) : "Output = 9, factors (3x3)",
}
selected_bits = {
    "Floating State": [-1, -2, -3, -4],  # Last 4 bits
    "Output = 6, factors (3x2,2x3)": [0, 1, 2, 3],  # First 4 bits
    "Output = 9, factors (3x3)": [0, 1, 2, 3]  # First 4 bits again
}
gbp.generate_bar_plots('Mult_behav.csv', label_mapping, savefig=False, save_csv=True, figWidth=8, selected_bits=selected_bits)
# Out:
# Labeled results saved to 'Mult_behav_behav_counts.csv'

# %%
import Scripts.generate_bar_plots as gbp

label_mapping = {
    ( 0., 0., 0., 0., -6., -1., -1., -4.) : "Floating State",
    ( 0., 0., 0., 0., -16., 15.875, 15.875, -16.) : "Output = 6, factors (3x2,2x3)",
    ( 0., 0., 0., 0., 15.875, -16., -16., 15.875) : "Output = 9, factors (3x3)",
}
selected_bits = {
    "Floating State": [-1, -2, -3, -4],  # Last 4 bits
    "Output = 6, factors (3x2,2x3)": [0, 1, 2, 3],  # First 4 bits
    "Output = 9, factors (3x3)": [0, 1, 2, 3]  # First 4 bits again
}
gbp.generate_bar_plots("Mult_behav_new_sample_method.csv", label_mapping, savefig=False, save_csv=True, figWidth=8, selected_bits=selected_bits)
# Out:
# Labeled results saved to 'Mult_behav_new_sample_method_behav_counts.csv'
