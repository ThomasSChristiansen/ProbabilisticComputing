# %%
import Scripts.comparison as comp
comp.comparison("Mult_behav_new_sample_method_behav_counts.csv","Integer_Factorization_counts.csv", savefig=True, filename="IntegerFactorization_Comparison")
# Out:
# Saved plot: Plots/IntegerFactorization_Comparison_Floating_State.png
# Saved plot: Plots/IntegerFactorization_Comparison_Output_=_6,_factors_(3x2,2x3).png
# Saved plot: Plots/IntegerFactorization_Comparison_Output_=_9,_factors_(3x3).png
