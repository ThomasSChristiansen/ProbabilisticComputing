# %%
import Scripts.generate_bar_plots as gbp

label_mapping = {
      (  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., -16., -16., -16., -6., -1., -1., -1., -1., -1., -1., -4., -2., -7., -7., -7., -7., -7., -7., -7., -5., -5., -5., -5., -2., -2., -2., -7., -7., -7., -7., -5.,
        -5., -5., -5., -2., -2., -2., -7., -7., -7., -7., -5., -5., -5.,-16.) : "Floating State",
}

selected_bits = {
    "Floating State": [0,1,2,3,4,5,6,7],
}
gbp.generate_bar_plots('Mult_behav.csv', label_mapping, savefig=True, save_csv=False, figWidth=68, selected_bits=selected_bits)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 11
#       3 label_mapping = {
#       4       (  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., -16., -16., -16., -6., -1., -1., -1., -1., -1., -1., -4., -2., -7., -7., -7., -7., -7., -7., -7., -5., -5., -5., -5., -2., -2., -2., -7., -7., -7., -7., -5.,
#       5         -5., -5., -5., -2., -2., -2., -7., -7., -7., -7., -5., -5., -5.,-16.) : "Floating State",
#       6 }
#       8 selected_bits = {
#       9     "Floating State": [0,1,2,3,4,5,6,7],
#      10 }
# ---> 11 gbp.generate_bar_plots('Mult_behav.csv', label_mapping, savefig=True, save_csv=False, figWidth=68, selected_bits=selected_bits)
#
# File C:\Repositories\ProbabilisticComputing\Scripts\generate_bar_plots.py:11, in generate_bar_plots(file_path, label_mapping, savefig, save_csv, figWidth, selected_bits)
#       8 base_name = os.path.splitext(os.path.basename(file_path))[0]
#      10 # Load the data
# ---> 11 data = pd.read_csv(file_path, low_memory=False)
#      12 data.columns = data.columns.str.strip()  # Remove whitespace from column names
#      14 # Automatically detect the number of h variables
#
# File c:\Repositories\ProbabilisticComputing\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Repositories\ProbabilisticComputing\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Repositories\ProbabilisticComputing\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Repositories\ProbabilisticComputing\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Repositories\ProbabilisticComputing\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Mult_behav.csv'

# %% [markdown]
# # non-optimized

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv("UniqueOccurrences_nonoptimized.csv", low_memory=False, dtype={'Pattern': str})
# print(df)
# print(df.head())
# print(df.info())
# Create a bar plot using the "Pattern" as the x-axis and "Occurrence" as the y-axis.
plt.figure(figsize=(28, 6))
plt.bar(df["Pattern"], df["Occurrence"]/df["Occurrence"].sum(), color='skyblue')
plt.xlabel("8-bit Pattern (binary)")
plt.ylabel("Occurrence")
plt.title("Output Occurrences")
plt.margins(x=0.01)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # CSR Optimized

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv("4bIntFac_test_UniqueOccurrences.csv", low_memory=False, dtype={'Pattern': str})
# print(df)
# print(df.head())
# print(df.info())
# Create a bar plot using the "Pattern" as the x-axis and "Occurrence" as the y-axis.
plt.figure(figsize=(28, 6))
plt.bar(df["Pattern"], df["Occurrence"]/df["Occurrence"].sum(), color='skyblue')
plt.xlabel("8-bit Pattern (binary)")
plt.ylabel("Occurrence")
plt.title("Output Occurrences")
plt.margins(x=0.01)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # ILA OUTPUT

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv("ila_output.csv", low_memory=False, dtype={'Pattern': str})
print(df)
print(df.head())
print(df.info())
# Create a bar plot using the "Pattern" as the x-axis and "Occurrence" as the y-axis.
plt.figure(figsize=(28, 6))
plt.bar(df["Pattern"], df["Occurrence"]/df["Occurrence"].sum(), color='skyblue')
plt.xlabel("8-bit Pattern (binary)")
plt.ylabel("Occurrence")
plt.title("Output Occurrences")
plt.margins(x=0.01)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
#       Pattern  Occurrence
# 0    00000000     2699869
# 1    00000001      207774
# 2    00000010      526532
# 3    00000011       36110
# 4    00000100      926874
# ..        ...         ...
# 251  11111011        8707
# 252  11111100      223466
# 253  11111101       39714
# 254  11111110       81211
# 255  11111111        3596
#
# [256 rows x 2 columns]
#     Pattern  Occurrence
# 0  00000000     2699869
# 1  00000001      207774
# 2  00000010      526532
# 3  00000011       36110
# 4  00000100      926874
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Pattern     256 non-null    object
#  1   Occurrence  256 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 4.1+ KB
# None

# %%
print(df.describe())
print(df.sort_values("Occurrence", ascending=False).head(10))
# Out:
#          Occurrence
# count  2.560000e+02
# mean   1.953125e+05
# std    2.687255e+05
# min    1.662000e+03
# 25%    2.939375e+04
# 50%    1.103930e+05
# 75%    2.568158e+05
# max    2.699869e+06
#      Pattern  Occurrence
# 0   00000000     2699869
# 8   00001000     1170105
# 16  00010000     1110337
# 24  00011000      948374
# 4   00000100      926874
# 32  00100000      782945
# 20  00010100      781402
# 12  00001100      777288
# 48  00110000      776068
# 40  00101000      743351

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv("iladata_TimeMUX.csv", low_memory=False, dtype={'Pattern': str})
# print(df)
# print(df.head())
# print(df.info())
# # Create a bar plot using the "Pattern" as the x-axis and "Occurrence" as the y-axis.
plt.figure(figsize=(28, 6))
plt.bar(df["Pattern"], df["Occurrence"]/df["Occurrence"].sum(), color='skyblue')
plt.xlabel("8-bit Pattern (binary)")
plt.ylabel("Occurrence")
plt.title("Output Occurrences")
plt.margins(x=0.01)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
df = pd.read_csv("iladata3_TimeMUX.csv", low_memory=False, dtype={'Pattern': str})
# print(df)
# print(df.head())
# print(df.info())
# # Create a bar plot using the "Pattern" as the x-axis and "Occurrence" as the y-axis.
plt.figure(figsize=(28, 6))
plt.bar(df["Pattern"], df["Occurrence"]/df["Occurrence"].sum(), color='skyblue')
plt.xlabel("8-bit Pattern (binary)")
plt.ylabel("Occurrence")
plt.title("Output Occurrences")
plt.margins(x=0.01)
plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
