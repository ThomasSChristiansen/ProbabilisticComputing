# %%
import Scripts.generate_bar_plots as gbp

# Use the function
label_mapping = {
    (-2.0, -2.0, -4.0): 'Floating State (I0=1)',
    (0.0, 0.0, 0.0): 'Unconstrained (I0=0)',
    (-2.0, -2.0, 15.875): 'C=1 (I0=1)',
    (15.875, -16.0, -4.0): 'A=1, B=0 (I0=1)',
    (15.875, 15.875, -4.0): 'A=1, B=1 (I0=1)',
    (-16.0, -16.0, -4.0): 'A=0, B=0 (I0=1)',
    (-16.0, 15.875, -4.0): 'A=0, B=1 (I0=1)',
    (-2.0, -2.0, -16.0): 'C=0 (I0=1)',
}
gbp.generate_bar_plots('OR_out.csv', label_mapping, savefig=False, save_csv=False)
